# %%
import pandas as pd
import os

# %%
file_path = 'datatest7.txt'

df = pd.read_csv(file_path, sep="\t", engine="python", on_bad_lines='skip')

pd.set_option('display.max_rows', 20) #Rows to display
pd.set_option('display.max_columns', 100)

# %%
df
# Out:
#              Timestamp  Longitude   Latitude Operatorname    Node  CellID  \
# 0  2025.02.12_10.23.18  10.405716  63.418165      Telia N  121687      11
# 1  2025.02.12_10.25.18  10.405716  63.418165      Telia N  121687      11
# 2  2025.02.12_10.27.19  10.405716  63.418165      Telia N  121687      11
# 3  2025.02.12_10.29.19  10.405716  63.418165      Telia N  121687      11
# 4  2025.02.12_10.31.19  10.405716  63.418165      Telia N  121687      11
# 5  2025.02.12_10.33.19  10.405716  63.418165      Telia N  121687      11
# 6  2025.02.12_10.35.20  10.405716  63.418165      Telia N  121687      11
# 7  2025.02.12_10.37.20  10.405716  63.418165      Telia N  121687      11
# 8  2025.02.12_10.39.20  10.405716  63.418165      Telia N  121687      11
#
#     LAC NetworkTech  Level  Qual   SNR CQI LTERSSI  PINGAVG  PINGMIN  PINGMAX  \
# 0  2305          5G   -105   -11   9.0   -       -       48       31       61
# ...
